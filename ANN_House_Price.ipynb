# %% [markdown]
# <a href="https://colab.research.google.com/github/Ram22nov/House_Price_Prediction/blob/main/ANN_House_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\Users\\Rameshwar\\OneDrive\\Desktop\\Tensorflow code notebook\\DATA\\kc_house_data.csv"
df = pd.read_csv(path)

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])
# Out:
# C:\Users\Rameshwar\AppData\Local\Temp\ipykernel_20064\4141105712.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
sns.boxplot(x='bedrooms', y='price',data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.scatterplot(x='long', y='price',data=df)
# Out:
# <Axes: xlabel='long', ylabel='price'>

# %%
sns.scatterplot(x='lat',y='price',data=df)
# Out:
# <Axes: xlabel='lat', ylabel='price'>

# %%
sns.scatterplot(x='long',y='lat',data=df,hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*(0.01)
# Out:
# 215.97

# %%
non_top_1_perc = df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',
                data=non_top_1_perc,hue='price',
                palette='RdYlGn',edgecolor=None,alpha=0.2)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df = df.drop('id',axis=1)

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['month']=df['date'].apply(lambda date:date.month)

# %%
df['year']=df['date'].apply(lambda date:date.year)

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
df = df.drop('date',axis=1)

# %%
df['zipcode'].value_counts()
# Out:
# zipcode
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: count, Length: 70, dtype: int64

# %%
df = df.drop('zipcode',axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
df['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: count, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: count, Length: 306, dtype: int64

# %%
X=df.drop('price',axis=1)

# %%
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train= scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (16197, 19)

# %%
X_test.shape
# Out:
# (5400, 19)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()
model.add(Dense(24,activation='relu'))
model.add(Dense(18,activation='relu'))
model.add(Dense(18,activation='relu'))
model.add(Dense(18,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train.values,validation_data=(X_test,y_test.values),batch_size=128,epochs=460)
# Out:
# Epoch 1/460
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 443063042048.0000 - val_loss: 411004829696.0000
# Epoch 2/460
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 429038141440.0000 - val_loss: 394117971968.0000
# Epoch 3/460
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 394004070400.0000 - val_loss: 223000346624.0000
# Epoch 4/460
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 195075670016.0000 - val_loss: 91495481344.0000
# Epoch 5/460
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 106406502400.0000 - val_loss: 89052340224.0000
# Epoch 6/460
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 100118552576.0000 - val_loss: 86590955520.0000
# Epoch 7/460
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 98590916608.0000 - val_loss: 83943194624.0000
# Epoch 8/460
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 86087081984.0000 - val_loss: 81321328640.0000
# Epoch 9/460
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,explained_variance_score

# %%
X_test
# Out:
# array([[0.1       , 0.06666667, 0.03510274, ..., 0.00874399, 0.63636364,
#         0.        ],
#        [0.3       , 0.3       , 0.14297945, ..., 0.00978817, 0.81818182,
#         0.        ],
#        [0.2       , 0.2       , 0.10359589, ..., 0.0053886 , 0.90909091,
#         0.        ],
#        ...,
#        [0.3       , 0.2       , 0.08732877, ..., 0.00551496, 1.        ,
#         0.        ],
#        [0.3       , 0.26666667, 0.31678082, ..., 0.11683195, 0.90909091,
#         0.        ],
#        [0.2       , 0.06666667, 0.08047945, ..., 0.00843269, 0.27272727,
#         1.        ]])

# %%
predictions=model.predict(X_test)
# Out:
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 95844.97671730325

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 154382.70634205503

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8118354850160537

# %%
df['price'].mean()
# Out:
# 540296.5735055795

# %%
df['price'].median()
# Out:
# 450000.0

# %%
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %%
errors = y_test.values.reshape(5400, 1) - predictions

# %%
sns.distplot(errors)
# Out:
# C:\Users\Rameshwar\AppData\Local\Temp\ipykernel_20064\2392254718.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(errors)
# <Axes: ylabel='Density'>
